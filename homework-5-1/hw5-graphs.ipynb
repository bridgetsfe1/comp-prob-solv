# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import expon
import overlap_H2 as fn

# %%
np.random.seed(42)
n_points_list = [10, 10**2, 10**3, 10**4, 10**5, 10**6, 10**7] #Kernel crahses for 10**8
L = 20
R = 2

S_R_rand = fn.random_sampling(n_points_list, L, R)
# Plot the results
plt.errorbar(n_points_list, S_R_rand, fmt ='o-', label ="S(R)")
plt.xscale('log')
plt.xlabel('Number of Points Sampled')
plt.ylabel('Overlap Integral Value')
plt.title('Overlap Integral of Two H 2$p_z$ Orbitals using Random Sampling')
plt.grid()
plt.legend()
plt.show()
print(S_R_rand)
# Out:
# [np.float64(1.6881844419966998), np.float64(0.1287487753506078), np.float64(0.5139728107272986), np.float64(0.8956833875185348), np.float64(0.7297168871170214), np.float64(0.7340704527388048), np.float64(0.7335399064707384)]

# %%
np.random.seed(42)
S_R_imp = fn.important_sampling(n_points_list, R)

plt.figure(figsize=(8, 6))
plt.plot(n_points_list, S_R_imp, 'o-', label ="S(R)")
plt.xlabel('Number of Points Sampled')
plt.xscale('log')
plt.ylabel('Overlap Integral Value')
plt.title('Overlap Integral of Two H 2$p_z$ Orbitals using Importance Sampling')
plt.grid()
plt.legend()
plt.show()
print(S_R_imp)
# Out:
# [np.float64(0.2884991942323775), np.float64(0.7457663859921035), np.float64(0.7555427776012446), np.float64(0.7374516856204877), np.float64(0.7364774242615065), np.float64(0.735002788717076), np.float64(0.7362047038787074)]
